# %% [markdown]
# 1. Chon du lieu dau vao la anh

# %%
import numpy as np

from PIL import Image
M = np.array(Image.open("anh.jpg").convert("L"), dtype = float) # Ma tran pixel (H, W)

print(M.shape)

# %% [markdown]
# 2. BÀI 1 BIỂU DIỄN DỮ LIỆU THÀNH MA TRẬN VÀ ĐỘ TƯƠNG ĐỒNG
